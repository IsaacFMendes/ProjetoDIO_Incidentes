# %% [markdown]
# <a href="https://colab.research.google.com/github/IsaacFMendes/ProjetoDIO_Incidentes/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# # Phishing para captura de senhas do Facebook
#
# ### Ferramentas
#
# - Kali Linux
# - setoolkit
#
# ### Configurando o Phishing no Kali Linux
#
# - Acesso root: `sudo su`
# - Iniciando o setoolkit: `setoolkit`
# - Tipo de ataque: `Social-Engineering Attacks`
# - Vetor de ataque: `Web Site Attack Vectors`
# - Método de ataque: `Credential Harvester Attack Method `
# - Método de ataque: `Site Cloner`
# - Obtendo o endereço da máquina: `ifconfig`
# - URL para clone: [http://www.facebook.com]

# %% [markdown]
# ### Resultados:

# %%
imagem_1 = cv2.imread("desafio_phishing_1.png")
cv2_imshow(imagem_1)
# Out:
# <PIL.Image.Image image mode=RGB size=999x661 at 0x7F4E0F389C70>

# %%
imagem_2 = cv2.imread("desafio_phishing_2.png")
cv2_imshow(imagem_2)
# Out:
# <PIL.Image.Image image mode=RGB size=1001x663 at 0x7F4E130B1CA0>
